# %% [markdown]
# # **&nbsp;TRABAJO FINAL DEL BOOTCAMP IV BIG DATA & MACHINE LEARNING**
#
#                                            Alumno  Francisco Javier Gonzálvez Chico
#                                            Título  Recomendador de Precios para Anfitriones de AirBNB España
#
#
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**CUADERNO DE TRABAJO 05**
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**El Modelo en Ejecución.**
#
# En los notebooks se codificarán las celdas con las que se procesarán las acciones sobre el dataset de trabajo y las ejecuciones de los modelos.
# No se comentarán ya que toda la documentación del trabajo se presentará en un documento Word en el que irá incluido este notebook.

# %%
def classif(data):
    errores = []
    data_in = []
    
    if data[0].lower() == "barcelona":
        data_in.append(0)
    elif data[0].lower() == "madrid":
        data_in.append(1)
    else:        
        errores.append("La ciudad debe ser Barcelona o Madrid")
    
    if len(data[1]) == 0:
        data_in.append(0)
    else:
        data_in.append(1)
        
    ngg_d = {"Vicálvaro": 1, "Villa de Vallecas": 2, "Moratalaz": 3, "Barajas": 4,
             "Villaverde": 5, "San Blas - Canillejas": 6, "Usera": 7,
             "Fuencarral - El Pardo": 8, "Hortaleza": 9, "Nou Barris": 10,
             "Puente de Vallecas": 11, "Sant Andreu": 12, "Ciudad Lineal": 13,
             "Les Corts": 14, "Chamartín": 15, "Carabanchel": 16, "Latina": 17,
             "Moncloa - Aravaca": 18, "Retiro": 19, "Retiro": 19, "Tetuán": 20,
             "Horta-Guinardó": 21, "Sarrià-Sant Gervasi": 22, "Arganzuela": 23,
             "Salamanca": 24, "Chamberí": 25, "Gràcia": 26, "Sant Martí": 27,
             "Sants-Montjuïc": 28, "Ciutat Vella": 29, "Eixample": 30, "Centro": 31}
    if data[2] in ngg_d:
        data_in.append(ngg_d[data[2]])
    else:
        data_in.append(0)
    
    n_d = {"Abrantes": 0, "Acacias": 1, "Adelfas": 2, "Aeropuerto": 3, "Aguilas": 4,
           "Alameda de Osuna": 5, "Almagro": 6, "Almenara": 7, "Almendrales": 8,
           "Aluche": 9, "Ambroz": 10, "Amposta": 11, "Apostol Santiago": 12,
           "Arapiles": 13, "Aravaca": 14, "Arcos": 15, "Argüelles": 16, "Atocha": 17,
           "Baró de Viver": 18, "Bellas Vistas": 19, "Berruguete": 20,
           "Buenavista": 21, "Butarque": 22, "Campamento": 23, "Can Baró": 24,
           "Can Peguera": 25, "Canillas": 26, "Canillejas": 27, "Canyelles": 28,
           "Casa de Campo": 29, "Casco Histórico de Barajas": 30,
           "Casco Histórico de Vallecas": 31, "Casco Histórico de Vicálvaro": 32,
           "Castellana": 33, "Castilla": 34, "Castillejos": 35, "Chopera": 36,
           "Ciudad Jardín": 37, "Ciudad Universitaria": 38, "Ciutat Meridiana": 39,
           "Colina": 40, "Comillas": 41, "Concepción": 42, "Corralejos": 43,
           "Cortes": 44, "Costillares": 45, "Cuatro Caminos": 46,
           "Cuatro Vientos": 47, "Cármenes": 48, "Delicias": 49,
           "Diagonal Mar i el Front Marítim del Poblenou": 50, "El Goloso": 51,
           "El Pardo": 52, "El Plantío": 53, "El Viso": 54, "Embajadores": 55,
           "Entrevías": 56, "Estrella": 57, "Fontarrón": 58, "Fuente del Berro": 59,
           "Fuentelareina": 60, "Gaztambide": 61, "Goya": 62, "Guindalera": 63,
           "Hellín": 64, "Hispanoamérica": 65, "Horta": 66, "Hostafrancs": 67,
           "Ibiza": 68, "Imperial": 69, "Jerónimos": 70, "Justicia": 71,
           "La Paz": 72, "Legazpi": 73, "Lista": 74, "Los Angeles": 75,
           "Los Rosales": 76, "Lucero": 77, "Marroquina": 78, "Media Legua": 79,
           "Mirasierra": 80, "Montbau": 81, "Moscardó": 82, "Navas": 83,
           "Niño Jesús": 84, "Nueva España": 85, "Numancia": 86, "Opañel": 87,
           "Orcasitas": 88, "Orcasur": 89, "Pacífico": 90, "Palacio": 91,
           "Palomas": 92, "Palomeras Bajas": 93, "Palomeras Sureste": 94,
           "Palos de Moguer": 95, "Pavones": 96, "Pedralbes": 97, "Peñagrande": 98,
           "Pilar": 99, "Pinar del Rey": 100, "Piovera": 101, "Porta": 102,
           "Portazgo": 103, "Pradolongo": 104, "Prosperidad": 105,
           "Provençals del Poblenou": 106, "Pueblo Nuevo": 107, "Puerta Bonita": 108,
           "Puerta del Angel": 109, "Quintana": 110, "Recoletos": 111, "Rejas": 112,
           "Rios Rosas": 113, "Rosas": 114, "Salvador": 115, "San Andrés": 116,
           "San Cristobal": 117, "San Diego": 118, "San Fermín": 119,
           "San Isidro": 120, "San Juan Bautista": 121, "San Pascual": 122,
           "Sant Andreu": 123, "Sant Antoni": 124, "Sant Genís dels Agudells": 125,
           "Sant Gervasi - Galvany": 126, "Sant Gervasi - la Bonanova": 127,
           "Sant Martí de Provençals": 128,
           "Sant Pere, Santa Caterina i la Ribera": 129, "Santa Eugenia": 130,
           "Sants": 131, "Sants - Badal": 132, "Sarrià": 133, "Simancas": 134,
           "Sol": 135, "Timón": 136, "Torre Baró": 137, "Trafalgar": 138, 
           "Universidad": 139, "Valdeacederas": 140, "Valdefuentes": 141,
           "Valdemarín": 142, "Valdezarza": 143, "Vallbona": 144, 
           "Vallcarca i els Penitents": 145, "Vallehermoso": 146,
           "Vallvidrera, el Tibidabo i les Planes": 147, "Valverde": 148,
           "Ventas": 149, "Verdun": 150, "Vilapicina i la Torre Llobeta": 151,
           "Vinateros": 152, "Vista Alegre": 153, "Zofío": 154,
           "el Baix Guinardó": 155, "el Barri Gòtic": 156,
           "el Besòs i el Maresme": 157, "el Bon Pastor": 158,
           "el Camp d'en Grassot i Gràcia Nova": 159,
           "el Camp de l'Arpa del Clot": 160, "el Carmel": 161, "el Clot": 162,
           "el Coll": 163, "el Congrés i els Indians": 164, "el Fort Pienc": 165,
           "el Guinardó": 166, "el Parc i la Llacuna del Poblenou": 167,
           "el Poble Sec": 168, "el Poblenou": 169, "el Putxet i el Farró": 170,
           "el Raval": 171, "el Turó de la Peira": 172,
           "l'Antiga Esquerra de l'Eixample": 173, "la Barceloneta": 174,
           "la Bordeta": 175, "la Dreta de l'Eixample": 176, 
           "la Font d'en Fargues": 177, "la Font de la Guatlla": 178,
           "la Guineueta": 179, "la Marina de Port": 180, 
           "la Marina del Prat Vermell": 181, "la Maternitat i Sant Ramon": 182,
           "la Nova Esquerra de l'Eixample": 183, "la Prosperitat": 184, 
           "la Sagrada Família": 185, "la Sagrera": 186, "la Salut": 187, 
           "la Teixonera": 188, "la Trinitat Nova": 189, "la Trinitat Vella": 190, 
           "la Vall d'Hebron": 191, "la Verneda i la Pau": 192, 
           "la Vila Olímpica del Poblenou": 193, "la Vila de Gràcia": 194, 
           "les Corts": 195, "les Roquetes": 196, "les Tres Torres": 197}
    if data[3] in n_d:
        data_in.append(n_d[data[3]])
    else:
        data_in.append(0)
    
    pt_d = {"Boutique hotel": 1, "Villa": 2, "Serviced apartment": 3, "Chalet": 4,
            "Hostel": 5, "Boat": 6, "Guesthouse": 7, "Dorm": 8, "Loft": 9,
            "Condominium": 10, "Bed & Breakfast": 11, "House": 12, "Apartment": 13}
    if data[4] in pt_d:
        data_in.append(pt_d[data[4]])
    else:
        data_in.append(0)
    
    rt_d = {"Shared room": 0, "Private room": 1, "Entire home/apt": 2}
    if data[5] in rt_d:
        data_in.append(rt_d[data[5]])
    else:
        data_in.append(0)
    
    try:
        data_in.append(int(data[6]))
    except:
        errores.append("El número de huespedes debe ser un entero")
    
    try:
        data_in.append(int(data[7]))
    except:
        errores.append("El número de invitados debe ser un entero")
    
    try:
        data_in.append(int(data[8]))
    except:
        errores.append("El número mínimo de noches debe ser un entero")
    
    try:
        data_in.append(int(data[9]))
    except:
        errores.append("El número máximo de noches debe ser un entero")
    
    cp_d = {"super_strict_60": 0, "super_strict_30": 1, "moderate": 2, "flexible": 3,
            "strict": 4}
    if data[10] in cp_d:
        data_in.append(cp_d[data[10]])
    else:
        data_in.append(0)
    
    try:
        data_in.append(float(data[11]))
    except:
        if data[5] == "Entire home/apt":
            data_in.append(1.0)
        else:
            data_in.append(0.0)
    
    data_in.append(len(data[12]))
    
    try:
        data_in.append(int(data[13]))
    except:
        data_in.append(0)
    
    try:
        data_in.append(int(data[14]))
    except:
        data_in.append(0)
    
    try:
        data_in.append(int(data[15]))
    except:
        data_in.append(0)
    
    if len(errores) == 0:
        from sklearn.externals import joblib
        import numpy as np
        
        data_in_values = np.asarray([data_in])
        xgbC = joblib.load('./modelo_XGBC.pkl')
        predict = xgbC.predict(data_in_values)
    else:
        predict = errores

    return predict

# %%
data = ['Madrid', '', 'Chamberí', 'Trafalgar', 'Apartment', 'Entire home/apt',
        5, 1, 2, 14, 'strict', 2.5, ['secador', 'calefaccion',
                                     'aire acondicionado', 'gel', 'champu',
                                     'TV', 'wifi'], 50, 200, 50]

print(f"Un {data[4]}, en {data[0]}, sito en el barrio de {data[3]}, distrito de " + 
      f"{data[2]}, que se\nalquila sin licencia, mínimo {data[8]} y máximo " + 
      f"{data[9]} noches, en regimen {data[5]}, para {data[6]}\nhuéspedes " +
      f"(+{data[7]} invitado opcional por {data[13]}€ la noche).\nAporta " + 
      f"{data[12]}\ny cuenta con {data[11]} baños.\nPolítica de Cancelación " + 
      f"{data[10]}. Fianza de {data[14]}€. Limpieza {data[15]}€.")

print(f"\nNuestro clasificador determina que su clase debe ser {classif(data)}.\n" + 
      "Estableciendo un rango de precios entre 50 ~ 100 €/noche.")
# Out:
# Un Apartment, en Madrid, sito en el barrio de Trafalgar, distrito de Chamberí, que se
# alquila sin licencia, mínimo 2 y máximo 14 noches, en regimen Entire home/apt, para 5
# huéspedes (+1 invitado opcional por 50€ la noche).
# Aporta ['secador', 'calefaccion', 'aire acondicionado', 'gel', 'champu', 'TV', 'wifi']
# y cuenta con 2.5 baños.
# Política de Cancelación strict. Fianza de 200€. Limpieza 50€.
#
# Nuestro clasificador determina que su clase debe ser [2.].
# Estableciendo un rango de precios entre 50 ~ 100 €/noche.

# %%
data2 = ['Barcelona', 'HUTB 003876', 'Gràcia', 'la Vila de Gràcia', 'Apartment',
         'Entire home/apt', 4, 0, 2, 30, 'strict', 1, ['secador', 'calefaccion',
                                                       'gel', 'champu', 'TV', 'wifi'],
         0, 100, 70]

print(f"Un {data2[4]}, en {data2[0]}, sito en el barrio de {data2[3]}, distrito de " + 
      f"{data2[2]},\nque se alquila con licencia, mínimo {data2[8]} y máximo " + 
      f"{data2[9]} noches, en regimen {data2[5]},\npara {data2[6]} huéspedes " + 
      f"(no permite invitados).\nAporta {data2[12]} y cuenta con {data2[11]} baño." + 
      f"\nPolítica de Cancelación {data2[10]}. Fianza de {data2[14]}€. Limpieza {data2[15]}€.")

print(f"\nNuestro clasificador determina que su clase debe ser {classif(data2)}.\n" + 
      "Estableciendo un rango de precios entre 50 ~ 100 €/noche.")
# Out:
# Un Apartment, en Barcelona, sito en el barrio de la Vila de Gràcia, distrito de Gràcia,
# que se alquila con licencia, mínimo 2 y máximo 30 noches, en regimen Entire home/apt,
# para 4 huéspedes (no permite invitados).
# Aporta ['secador', 'calefaccion', 'gel', 'champu', 'TV', 'wifi'] y cuenta con 1 baño.
# Política de Cancelación strict. Fianza de 100€. Limpieza 70€.
#
# Nuestro clasificador determina que su clase debe ser [2.].
# Estableciendo un rango de precios entre 50 ~ 100 €/noche.
